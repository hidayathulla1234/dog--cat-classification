# %% [markdown]
# Topis:
#
#
# *   Reading an image  and converting into a numpy array
# *  Resizing an image
# *   RGB to GrayScale conversion

# %%
#getting an image using web get
# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRFhLiRvG4XHezJ6W7E7eSPdoWbVEJQoh9OXQ&s'
# Out:
# --2026-01-30 11:07:36--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRFhLiRvG4XHezJ6W7E7eSPdoWbVEJQoh9OXQ&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 173.194.195.100, 173.194.195.101, 173.194.195.139, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|173.194.195.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5837 (5.7K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcRFhLiRvG4XHezJ6W7E7eSPdoWbVEJQoh9OXQ&s.1’
#
# images?q=tbn:ANd9Gc 100%[===================>]   5.70K  --.-KB/s    in 0s
#
# 2026-01-30 11:07:36 (67.1 MB/s) - ‘images?q=tbn:ANd9GcRFhLiRvG4XHezJ6W7E7eSPdoWbVEJQoh9OXQ&s.1’ saved [5837/5837]

# %% [markdown]
# **libraries used for image proecessing**
#
#
# 1.  matplotlib.image
#
# 2.   pillow
#
# 1.   Open CV(cv2)
# 2.

# %%
#importing the iamge module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#Loading an image through matplotlib.image library
img=mpimg.imread('/content/images?q=tbn:ANd9GcRFhLiRvG4XHezJ6W7E7eSPdoWbVEJQoh9OXQ&s.1')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (168, 299, 3)

# %%
print(img)
# Out:
# [[[162 177 174]
#   [163 178 175]
#   [164 179 176]
#   ...
#   [170 196 211]
#   [170 196 211]
#   [170 196 211]]
#
#  [[162 177 174]
#   [162 177 174]
#   [163 178 175]
#   ...
#   [170 196 211]
#   [170 196 211]
#   [170 196 211]]
#
#  [[161 176 173]
#   [161 176 173]
#   [162 177 174]
#   ...
#   [170 196 211]
#   [170 196 211]
#   [170 196 211]]
#
#  ...
#
#  [[107  96  64]
#   [106  95  63]
#   [104  93  61]
#   ...
#   [ 97  87  62]
#   [ 97  87  62]
#   [ 97  87  62]]
#
#  [[104  93  63]
#   [103  92  62]
#   [102  91  61]
#   ...
#   [ 97  87  60]
#   [ 97  87  60]
#   [ 97  87  60]]
#
#  [[103  92  64]
#   [102  91  63]
#   [100  89  61]
#   ...
#   [ 96  86  59]
#   [ 97  87  60]
#   [ 97  87  60]]]

# %%
#displaying the image from numpy array
plt.imshow(img)
plt.show()

# %%
# resizing the image using pillow library
from PIL import Image

# %%
img=Image.open('/content/images?q=tbn:ANd9GcRFhLiRvG4XHezJ6W7E7eSPdoWbVEJQoh9OXQ&s.1')

# %%
img_resized = img.resize((200,200))

# %%
img_resized.save('cat_image_resized.jpg')

# %%
img_resized=mpimg.imread('/content/cat_image_resized.jpg')
img_resized=plt.imshow(img_resized)
plt.show()

# %%
import matplotlib.image as mpimg

# Reload the image to get its shape as a NumPy array
img_data_for_shape = mpimg.imread('/content/cat_image_resized.jpg')
print(img_data_for_shape.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Converting RGB images into Gray Scale Images

# %%
#importing open CV Library

import cv2

# %%
img=cv2.imread('/content/images?q=tbn:ANd9GcRFhLiRvG4XHezJ6W7E7eSPdoWbVEJQoh9OXQ&s')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (168, 299, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (168, 299)

# %%
cv2.imshow(will display the image . But this will be not allowwed in google collab)
# Out:
#   File "/tmp/ipython-input-3361704331.py", line 1
#     cv2.imshow(will display the image . But this will be not allowwed in google collab)
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
